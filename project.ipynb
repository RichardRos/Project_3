# %%
import yfinance as yf
from financetoolkit import Toolkit

# %%
# Gather Key Ratios
companies = Toolkit(
    tickers=['BYDIY', 'ONTO', 'COHR', 'BYDIF', 'OLED','MKSI', 'OMRNY', 'AMKR', 'SOTGY', 'FN', 'SNPTF', 'CGNX', 'VNT', 'LFUS', 'SUMCF', 'NOVT', 'HPHTF', 'SUOPY', 'SLOIF', 'SEKEY', 'ST', 'CLS', 'NVMI', 'ASMVY', 'SEPJF', 'BMI', 'AUOTY', 'HRIBF', 'ITRI', 'AIXXF', 'IPGP', 'RNSHF', 'HROEY', 'CAMT', 'ACLS', 'SHCAY', 'SANM', 'LPL', 'VEMLY', 'TYOYY', 'KLIC', 'ESE', 'PLXS', 'IONQ', 'AMBA', 'SONO', 'OSIS', 'VZIO', 'ROG', 'KGBLY'],
    api_key='DhSKlDzkmluzGeZ4mK9mvI0lQDUDmRpa',
    start_date='2019-02-28'
)

# %%
bal_sheet
# Out:
#      index level_0                                      level_1   2019  \
# 0        0    ACLS                                 Gross Margin 0.4203
# 1        1    ACLS                             Operating Margin 0.0531
# 2        2    ACLS                            Net Profit Margin 0.0497
# 3        3    ACLS                      Interest Coverage Ratio 5.0586
# 4        4    ACLS              Income Before Tax Profit Margin  0.061
# ..     ...     ...                                          ...    ...
# 779    779    VZIO                         Income Quality Ratio 3.4589
# 780    780    VZIO                           Net Income per EBT   0.75
# 781    781    VZIO  Free Cash Flow to Operating Cash Flow Ratio   0.99
# 782    782    VZIO                            EBT to EBIT Ratio    1.0
# 783    783    VZIO                              EBIT to Revenue 0.0168
#
#        2020    2021    2022    2023
# 0    0.4185  0.4324  0.4367  0.4345
# 1    0.1223  0.1922  0.2308  0.2351
# ...

# %%
# Get proper statements
stock = yf.Ticker('ACLS')

balance_sheet = stock.get_balance_sheet()
income_statement = stock.get_income_stmt()
fcf = stock.get_cashflow()

# %%
display(revenue_statement)
display(balance_sheet)
display(fcf)
# Out:
#                                                      2023-12-31  2022-12-31  \
# TaxEffectOfUnusualItems                                     0.0         0.0
# TaxRateForCalcs                                           0.116       0.106
# NormalizedEBITDA                                    297015000.0 222068000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  246263000.0 183079000.0
# ReconciledDepreciation                               13069000.0  11607000.0
# ReconciledCostOfRevenue                             639303000.0 518208000.0
# EBITDA                                              297015000.0 222068000.0
# EBIT                                                283946000.0 210461000.0
# NetInterestIncome                                    12852000.0  -1025000.0
# InterestExpense                                       5347000.0   5576000.0
# InterestIncome                                       18199000.0   4551000.0
# ...

# %%
ticker = yf.Ticker('AAPL')

# %%
dir(ticker)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_base_url',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fix_bad_stock_split',
#  '_fix_missing_div_adjust',
#  '_fix_prices_sudden_change',
#  '_fix_unit_mixups',
#  '_fix_unit_random_mixups',
#  '_fix_unit_switch',
#  '_fix_zeroes',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_history',
#  '_history_metadata',
#  '_history_metadata_formatted',
#  '_holders',
#  '_isin',
#  '_news',
#  '_options2df',
#  '_quote',
# ...

# %%
forecast= stock.get_rev_forecast()
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 forecast= stock.get_rev_forecast()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\yfinance\base.py:1772, in TickerBase.get_rev_forecast(self, proxy, as_dict)
#    1770 def get_rev_forecast(self, proxy=None, as_dict=False):
#    1771     self._analysis.proxy = proxy
# -> 1772     data = self._analysis.rev_est
#    1773     if as_dict:
#    1774         return data.to_dict()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\yfinance\scrapers\analysis.py:43, in Analysis.rev_est(self)
#      40 @property
#      41 def rev_est(self) -> pd.DataFrame:
#      42     if self._rev_est is None:
# ...

# %%
forecast
# Out:
# <bound method TickerBase.get_rev_forecast of yfinance.Ticker object <ACLS>>

# %%
print(forecast)
# Out:
# <bound method TickerBase.get_rev_forecast of yfinance.Ticker object <ACLS>>

# %%
from financetoolkit import Toolkit
import yfinance as yf
import pandas as pd

# %%
stock = yf.Ticker("ACLS")
balance_sheet = stock.get_balance_sheet()

# %%
balance_sheet.head(50)
# Out:
#                                                     2023-12-31    2022-12-31  \
# OrdinarySharesNumber                                32685000.0    32775000.0
# ShareIssued                                         32685000.0    32775000.0
# TotalDebt                                           45185000.0    46414000.0
# TangibleBookValue                                  864882000.0   667256000.0
# InvestedCapital                                    864882000.0   667256000.0
# WorkingCapital                                     794862000.0   629513000.0
# NetTangibleAssets                                  864882000.0   667256000.0
# CapitalLeaseObligations                             45185000.0    46414000.0
# CommonStockEquity                                  864882000.0   667256000.0
# TotalCapitalization                                864882000.0   667256000.0
# TotalEquityGrossMinorityInterest                   864882000.0   667256000.0
# StockholdersEquity                                 864882000.0   667256000.0
# GainsLossesNotAffectingRetainedEarnings             -1846000.0    -1968000.0
# OtherEquityAdjustments                              -1846000.0    -1968000.0
# RetainedEarnings                                   319506000.0   118892000.0
# AdditionalPaidInCapital                            547189000.0   550299000.0
# CapitalStock                                           33000.0       33000.0
# CommonStock                                            33000.0       33000.0
# TotalLiabilitiesNetMinorityInterest                417085000.0   346385000.0
# TotalNonCurrentLiabilitiesNetMinorityInterest      131956000.0    98253000.0
# OtherNonCurrentLiabilities                          42074000.0    21762000.0
# NonCurrentDeferredLiabilities                       46208000.0    31306000.0
# NonCurrentDeferredRevenue                           46208000.0    31306000.0
# LongTermDebtAndCapitalLeaseObligation               43674000.0    45185000.0
# LongTermCapitalLeaseObligation                      43674000.0    45185000.0
# CurrentLiabilities                                 285129000.0   248132000.0
# OtherCurrentLiabilities                             12834000.0    12943000.0
# CurrentDeferredLiabilities                         164677000.0   123471000.0
# CurrentDeferredRevenue                             164677000.0   123471000.0
# CurrentDebtAndCapitalLeaseObligation                 1511000.0     1229000.0
# CurrentCapitalLeaseObligation                        1511000.0     1229000.0
# PensionandOtherPostRetirementBenefitPlansCurrent    31445000.0    35540000.0
# CurrentProvisions                                   14098000.0     8299000.0
# PayablesAndAccruedExpenses                          60564000.0    66650000.0
# Payables                                            60564000.0    66650000.0
# TotalTaxPayable                                      6164000.0     4304000.0
# IncomeTaxPayable                                     6164000.0     4304000.0
# AccountsPayable                                     54400000.0    62346000.0
# TotalAssets                                       1281967000.0  1013641000.0
# TotalNonCurrentAssets                              201976000.0   135996000.0
# OtherNonCurrentAssets                               47229000.0    34543000.0
# NonCurrentDeferredAssets                            53428000.0    31701000.0
# NonCurrentDeferredTaxesAssets                       53428000.0    31701000.0
# NetPPE                                             101319000.0    69752000.0
#
#                                                    2021-12-31   2020-12-31
# OrdinarySharesNumber                               33240000.0   33633000.0
# ShareIssued                                        33240000.0   33633000.0
# TotalDebt                                          47394000.0   48149000.0
# TangibleBookValue                                 538959000.0  481602000.0
# InvestedCapital                                   538959000.0  481602000.0
# WorkingCapital                                    469106000.0  386360000.0
# NetTangibleAssets                                 538959000.0  481602000.0
# CapitalLeaseObligations                            47394000.0   48149000.0
# CommonStockEquity                                 538959000.0  481602000.0
# TotalCapitalization                               538959000.0  481602000.0
# TotalEquityGrossMinorityInterest                  538959000.0  481602000.0
# StockholdersEquity                                538959000.0  481602000.0
# GainsLossesNotAffectingRetainedEarnings             1765000.0    3435000.0
# OtherEquityAdjustments                              1765000.0    3435000.0
# RetainedEarnings                                  -22722000.0  -91969000.0
# AdditionalPaidInCapital                           559883000.0  570102000.0
# CapitalStock                                          33000.0      34000.0
# CommonStock                                           33000.0      34000.0
# TotalLiabilitiesNetMinorityInterest               214281000.0  143022000.0
# TotalNonCurrentLiabilitiesNetMinorityInterest      64141000.0   58591000.0
# OtherNonCurrentLiabilities                          9744000.0    9361000.0
# NonCurrentDeferredLiabilities                       7982000.0    1837000.0
# NonCurrentDeferredRevenue                           7982000.0    1837000.0
# LongTermDebtAndCapitalLeaseObligation              46415000.0   47393000.0
# LongTermCapitalLeaseObligation                     46415000.0   47393000.0
# CurrentLiabilities                                150140000.0   84431000.0
# OtherCurrentLiabilities                            12639000.0    8945000.0
# CurrentDeferredLiabilities                         60454000.0   21221000.0
# CurrentDeferredRevenue                             60454000.0   21221000.0
# CurrentDebtAndCapitalLeaseObligation                 979000.0     756000.0
# CurrentCapitalLeaseObligation                        979000.0     756000.0
# PensionandOtherPostRetirementBenefitPlansCurrent   30732000.0   24562000.0
# CurrentProvisions                                   6424000.0    4280000.0
# PayablesAndAccruedExpenses                         38912000.0   24667000.0
# Payables                                           38912000.0   24667000.0
# TotalTaxPayable                                      887000.0     654000.0
# IncomeTaxPayable                                     887000.0     654000.0
# AccountsPayable                                    38025000.0   24013000.0
# TotalAssets                                       753240000.0  624624000.0
# TotalNonCurrentAssets                             133994000.0  153833000.0
# OtherNonCurrentAssets                              35088000.0   41056000.0
# NonCurrentDeferredAssets                           35454000.0   57851000.0
# NonCurrentDeferredTaxesAssets                      35454000.0   57851000.0
# NetPPE                                             63452000.0   54926000.0

# %%
# income_statement = pd.DataFrame(stock.get_income_stmt())
income_statement = stock.get_income_stmt()

# %%
income_statement.loc['EBITDA']['2023-12-31']
# Out:
# 297015000.0

# %%
display(income_statement)
# Out:
#                                                       2023-12-31   2022-12-31  \
# TaxEffectOfUnusualItems                                      0.0          0.0
# TaxRateForCalcs                                            0.116        0.106
# NormalizedEBITDA                                     297015000.0  222068000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   246263000.0  183079000.0
# ReconciledDepreciation                                13069000.0   11607000.0
# ReconciledCostOfRevenue                              639303000.0  518208000.0
# EBITDA                                               297015000.0  222068000.0
# EBIT                                                 283946000.0  210461000.0
# NetInterestIncome                                     12852000.0   -1025000.0
# InterestExpense                                        5347000.0    5576000.0
# InterestIncome                                        18199000.0    4551000.0
# NormalizedIncome                                     246263000.0  183079000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      246263000.0  183079000.0
# TotalExpenses                                        864809000.0  707637000.0
# TotalOperatingIncomeAsReported                       265795000.0  212361000.0
# DilutedAverageShares                                  33165000.0   33542000.0
# BasicAverageShares                                    32758000.0   33043000.0
# DilutedEPS                                                  7.43         5.46
# BasicEPS                                                    7.52         5.54
# DilutedNIAvailtoComStockholders                      246263000.0  183079000.0
# NetIncomeCommonStockholders                          246263000.0  183079000.0
# NetIncome                                            246263000.0  183079000.0
# NetIncomeIncludingNoncontrollingInterests            246263000.0  183079000.0
# NetIncomeContinuousOperations                        246263000.0  183079000.0
# TaxProvision                                          32336000.0   21806000.0
# PretaxIncome                                         278599000.0  204885000.0
# OtherIncomeExpense                                      -48000.0   -6451000.0
# OtherNonOperatingIncomeExpenses                         -48000.0   -6451000.0
# NetNonOperatingInterestIncomeExpense                  12852000.0   -1025000.0
# InterestExpenseNonOperating                            5347000.0    5576000.0
# InterestIncomeNonOperating                            18199000.0    4551000.0
# OperatingIncome                                      265795000.0  212361000.0
# OperatingExpense                                     225506000.0  189429000.0
# ResearchAndDevelopment                                96907000.0   78356000.0
# SellingGeneralAndAdministration                      128599000.0  111073000.0
# SellingAndMarketingExpense                            62805000.0   53599000.0
# GeneralAndAdministrativeExpense                       65794000.0   57474000.0
# OtherGandA                                            65794000.0   57474000.0
# GrossProfit                                          491301000.0  401790000.0
# CostOfRevenue                                        639303000.0  518208000.0
# TotalRevenue                                        1130604000.0  919998000.0
# OperatingRevenue                                    1130604000.0  919998000.0
#
#                                                      2021-12-31   2020-12-31
# TaxEffectOfUnusualItems                                     0.0          0.0
# TaxRateForCalcs                                           0.181     0.105644
# NormalizedEBITDA                                    136081000.0   71036000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   98650000.0   49982000.0
# ReconciledDepreciation                               10818000.0    9939000.0
# ReconciledCostOfRevenue                             375983000.0  275976000.0
# EBITDA                                              136081000.0   71036000.0
# EBIT                                                125263000.0   61097000.0
# NetInterestIncome                                    -4626000.0   -4473000.0
# InterestExpense                                       4835000.0    5211000.0
# InterestIncome                                         209000.0     738000.0
# NormalizedIncome                                     98650000.0   49982000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      98650000.0   49982000.0
# TotalExpenses                                       535103000.0  416519000.0
# TotalOperatingIncomeAsReported                      127325000.0   58041000.0
# DilutedAverageShares                                 34268000.0   34128000.0
# BasicAverageShares                                   33555000.0   33257000.0
# DilutedEPS                                                 2.88         1.46
# BasicEPS                                                   2.94          1.5
# DilutedNIAvailtoComStockholders                      98650000.0   49982000.0
# NetIncomeCommonStockholders                          98650000.0   49982000.0
# NetIncome                                            98650000.0   49982000.0
# NetIncomeIncludingNoncontrollingInterests            98650000.0   49982000.0
# NetIncomeContinuousOperations                        98650000.0   49982000.0
# TaxProvision                                         21778000.0    5904000.0
# PretaxIncome                                        120428000.0   55886000.0
# OtherIncomeExpense                                   -2271000.0    2318000.0
# OtherNonOperatingIncomeExpenses                      -2271000.0    2318000.0
# NetNonOperatingInterestIncomeExpense                 -4626000.0   -4473000.0
# InterestExpenseNonOperating                           4835000.0    5211000.0
# InterestIncomeNonOperating                             209000.0     738000.0
# OperatingIncome                                     127325000.0   58041000.0
# OperatingExpense                                    159120000.0  140543000.0
# ResearchAndDevelopment                               65431000.0   61833000.0
# SellingGeneralAndAdministration                      93689000.0   78710000.0
# SellingAndMarketingExpense                           47548000.0   38746000.0
# GeneralAndAdministrativeExpense                      46141000.0   39964000.0
# OtherGandA                                           46141000.0   39964000.0
# GrossProfit                                         286445000.0  198584000.0
# CostOfRevenue                                       375983000.0  275976000.0
# TotalRevenue                                        662428000.0  474560000.0
# OperatingRevenue                                    662428000.0  474560000.0

# %%
# Initialize a DataFrame for the information we want
stock_df = pd.DataFrame(index=['ticker'],columns=[
    'gross_profit_margin'
    'ebit',
    'return_on_sales',
    'return_on_assets',
    'return_on_equity',
    'ebitda',
    'basic_eps'
])

# %%
stock_df
# Out:
#        gross_profit_marginebit return_on_sales return_on_assets  \
# ticker                     NaN             NaN              NaN
#
#        return_on_equity ebitda basic_eps
# ticker              NaN    NaN       NaN

# %%
list_of_tickers = [
'BYDIY',
# 'ONTO',
# 'COHR',
# 'BYDIF',
# 'OLED',
# 'MKSI',
# 'OMRNY',
# 'AMKR',
# 'SOTGY',
# 'FN',
# 'SNPTF',
# 'CGNX',
# 'VNT',
# 'LFUS',
# 'SUMCF',
# 'NOVT',
# 'HPHTF',
# 'SUOPY',
# 'SLOIF',
# 'SEKEY',
# 'ST',
# 'CLS',
# 'NVMI',
# 'ASMVY',
# 'SEPJF',
# 'BMI',
# 'AUOTY',
# 'HRIBF',
# 'ITRI',
# 'AIXXF',
# 'IPGP',
# 'RNSHF',
# 'HROEY',
# 'CAMT',
# 'ACLS',
# 'SHCAY',
# 'SANM',
# 'LPL',
# 'VEMLY',
# 'TYOYY',
# 'KLIC',
# 'ESE',
# 'PLXS',
# 'IONQ',
# 'AMBA',
# 'SONO',
# 'OSIS',
# 'VZIO',
# 'ROG',
# 'KGBLY'
]

# %%
# Create a loop for all of the ticker symbols
for ticker_symbol in list_of_tickers:
    # For each ticker, grab the data from yfinance
    stock = yf.Ticker(ticker_symbol)
    balance_sheet = stock.get_balance_sheet()
    income_statement = stock.get_income_stmt()
    
    # # Grab or derive the parameters that we're interested in
    # Gross_Profit_Margin = Gross_Profit -
    gross_profit_margin = income_statement.loc['GrossProfit']['2023-12-31']
    
    # EBIT comes from the income statement
    ebit = income_statement.loc['EBIT']['2023-12-31']
    # Return_on_Sales = EBIT / Total_Revenue
    return_on_sales = ebit / ( income_statement.loc['TotalRevenue']['2023-12-31'] )
    # Grab the Net_Income
    net_income = income_statement.loc['NetIncome']['2023-12-31']
    # Return_on_Assets = Net_Income / Total_Assets
    return_on_assets = net_income / ( balance_sheet.loc['TotalAssets']['2023-12-31'] )
    # Return_on_Equity = Net_Income / Shareholder_Equity
    return_on_equity = net_income / ( balance_sheet.loc['StockholdersEquity']['2023-12-31'] )
    # EBITDA comes from the income statement
    ebitda = income_statement.loc['EBITDA']['2023-12-31']
    # Basic EPS comes from the incmoe statement
    basic_eps = income_statement.loc['BasicEPS']['2023-12-31']

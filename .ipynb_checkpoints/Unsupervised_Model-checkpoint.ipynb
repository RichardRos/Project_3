# %% [markdown]
# ## Import statements

# %%
# Import Statements

from financetoolkit import Toolkit
import yfinance as yf
import pandas as pd
from pathlib import Path

# %%
api_key = 'DhSKlDzkmluzGeZ4mK9mvI0lQDUDmRpa'

# %% [markdown]
# ## Sample financetoolkit syntax

# %%
# Sample

# companies = Toolkit(
#     tickers=['ACLS'],
#     api_key=api_key,
# )

# balance_sheet = companies.get_balance_sheet_statement()
# income_statement = companies.get_income_statement()
# # cash_flow_statement = companies.get_cash_flow_statement()

# %%
# balance_sheet.head(50)

# %%
# income_statement.head(50)

# %% [markdown]
# ## Initialize a DataFrame for the stock data

# %%
# Initialize a DataFrame for the stock data
stock_df = pd.DataFrame(columns=[
    'year',
    'gross_profit_margin',
    'ebit',
    'return_on_sales',
    'return_on_assets',
    'return_on_equity',
    'ebitda',
    'eps'
])

# %%
stock_df
# Out:
# Empty DataFrame
# Columns: [year, gross_profit_margin, ebit, return_on_sales, return_on_assets, return_on_equity, ebitda, eps]
# Index: []

# %% [markdown]
# ## Create a list of ticker symbols

# %%
list_of_tickers = [
'BYDIY',
'ONTO',
'COHR',
# 'BYDIF',
# 'OLED',
# 'MKSI',
# 'OMRNY',
# 'AMKR',
# 'SOTGY',
# 'FN',
# 'SNPTF',
# 'CGNX',
# 'VNT',
# 'LFUS',
# 'SUMCF',
# 'NOVT',
# 'HPHTF',
# 'SUOPY',
# 'SLOIF',
# 'SEKEY',
# 'ST',
# 'CLS',
# 'NVMI',
# 'ASMVY',
# 'SEPJF',
# 'BMI',
# 'AUOTY',
# 'HRIBF',
# 'ITRI',
# 'AIXXF',
# 'IPGP',
# 'RNSHF',
# 'HROEY',
# 'CAMT',
# 'ACLS',
# 'SHCAY',
# 'SANM',
# 'LPL',
# 'VEMLY',
# 'TYOYY',
# 'KLIC',
# 'ESE',
# 'PLXS',
# 'IONQ',
# 'AMBA',
# 'SONO',
# 'OSIS',
# 'VZIO',
# 'ROG',
# 'KGBLY'
]

# %% [markdown]
# ## YFinance Approach
#
# Note: we switched to using financetoolkit instead

# %%
# # # Yahoo Finance Approach
# # Create a loop for all of the ticker symbols
# for ticker_symbol in list_of_tickers:
#     # For each ticker, grab the data from yfinance
#     stock = yf.Ticker(ticker_symbol)
#     balance_sheet = stock.get_balance_sheet()
#     income_statement = stock.get_income_stmt()
    
#     # # Grab or derive the parameters that we're interested in
#     # Gross_Profit_Margin = Gross_Profit -
#     gross_profit_margin = income_statement.loc['GrossProfit']['2023-12-31']
    
#     # EBIT comes from the income statement
#     ebit = income_statement.loc['EBIT']['2023-12-31']
#     # Return_on_Sales = EBIT / Total_Revenue
#     return_on_sales = ebit / ( income_statement.loc['TotalRevenue']['2023-12-31'] )
#     # Grab the Net_Income
#     net_income = income_statement.loc['NetIncome']['2023-12-31']
#     # Return_on_Assets = Net_Income / Total_Assets
#     return_on_assets = net_income / ( balance_sheet.loc['TotalAssets']['2023-12-31'] )
#     # Return_on_Equity = Net_Income / Shareholder_Equity
#     return_on_equity = net_income / ( balance_sheet.loc['StockholdersEquity']['2023-12-31'] )
#     # EBITDA comes from the income statement
#     ebitda = income_statement.loc['EBITDA']['2023-12-31']
#     # Basic EPS comes from the incmoe statement
#     basic_eps = income_statement.loc['BasicEPS']['2023-12-31']

# %% [markdown]
# ## Financetoolkit approach

# %%
# # FinanceToolkit Approach
# Create a loop for all of the ticker symbols
for ticker_symbol in list_of_tickers:
    
    # For each ticker, grab the data from FinanceToolkit
    stock = Toolkit(
        tickers=[ticker_symbol],
        api_key=api_key,
    )
    balance_sheet = stock.get_balance_sheet_statement()
    income_statement = stock.get_income_statement()

    # Grab the most recent year of available data for the stock
    year = max(balance_sheet.columns)
    
    # # Grab or derive the parameters that we're interested in
    # Gross_Profit_Margin = Gross_Profit - Cost of Goods Sold
    gross_profit_margin = income_statement.loc['Gross Profit'][year] - income_statement.loc['Cost of Goods Sold'][year]
    # EBIT comes from the income statement
    ebit = income_statement.loc['EBITDA'][year] + income_statement.loc['Depreciation and Amortization'][year]
    # Return_on_Sales = EBIT / Total_Revenue
    return_on_sales = ebit / ( income_statement.loc['Revenue'][year] )
    # Grab the Net_Income
    net_income = income_statement.loc['Net Income'][year]
    # Return_on_Assets = Net_Income / Total_Assets
    return_on_assets = net_income / ( balance_sheet.loc['Total Assets'][year] )
    # Return_on_Equity = Net_Income / Shareholder_Equity
    return_on_equity = net_income / ( balance_sheet.loc['Total Shareholder Equity'][year] )
    # EBITDA comes from the income statement
    ebitda = income_statement.loc['EBITDA'][year]
    # Basic EPS comes from the incmoe statement
    eps = income_statement.loc['EPS'][year]

    # Add the values to a DataFrame
    temp_df = pd.DataFrame(
        {
        'year': year,
        'gross_profit_margin': gross_profit_margin,
        'ebit': ebit,
        'return_on_sales': return_on_sales,
        'return_on_assets': return_on_assets,
        'return_on_equity': return_on_equity,
        'ebitda': ebitda,
        'eps': eps
        },
    index=[ticker_symbol]
    )
    # Concatenate the temporary dataframe to the one that holds the rest of the stock values
    stock_df = pd.concat([stock_df, temp_df], axis="rows")
# Out:
# Obtaining balance data: 100%|████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.45it/s]
# Obtaining income data: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.87it/s]
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_30280\2559166520.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stock_df = pd.concat([stock_df, temp_df], axis="rows")
# Obtaining balance data: 100%|████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.51it/s]
# Obtaining income data: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.54it/s]
# Obtaining balance data: 100%|████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.59it/s]
# Obtaining income data: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.34it/s]

# %%
stock_df
# Out:
#        year  gross_profit_margin         ebit     return_on_sales  \
# BYDIY  2022       -94485752000.0 7854485000.0 0.07327882275389554
# ONTO   2023          -70950000.0  261100000.0  0.3200272593115553
# COHR   2023        -1923534000.0  732102000.0  0.1418774829945156
#
#            return_on_assets     return_on_equity       ebitda   eps
# BYDIY   0.03259300703246617  0.07246393602451393 4937601000.0  41.0
# ONTO    0.06344359777809429  0.06977054882279943  193888000.0  2.46
# COHR  -0.018923162659132547 -0.05202112219002873   50415000.0 -1.89

# %%
stock_df.to_csv(Path('./Data_Files/stock_data.csv'))

# %%
balance_sheet.head(50)
# Out:
# date                                              2018          2019  \
# Cash and Cash Equivalents                 4741377000.0  1650730000.0
# Short Term Investments                             0.0           0.0
# Other Liabilities                                  0.0           0.0
# Capital Lease Obligations                  735580000.0   509765000.0
# Total Liabilities                        15703795000.0 17148179000.0
# Preferred Stock                                    0.0           0.0
# Common Stock                              4052228000.0  4052228000.0
# Retained Earnings                                  0.0 19207026000.0
# Accumulated Other Comprehensive Income             0.0           0.0
# Other Total Shareholder Equity           18220065000.0   767849000.0
# Total Shareholder Equity                 22272293000.0 24027103000.0
# Total Equity                             22272293000.0 24027103000.0
# Total Liabilities and Shareholder Equity 37976088000.0 41175282000.0
# Minority Interest                                  0.0           0.0
# Total Liabilities and Equity             37976088000.0 41175282000.0
# Total Investments                           14593000.0   170215000.0
# Total Debt                                2744827000.0   509765000.0
# Net Debt                                  -721062000.0 -2314976000.0
#
# date                                              2022
# Cash and Cash Equivalents                 6243678000.0
# Short Term Investments                             0.0
# Cash and Short Term Investments           6243678000.0
# Accounts Receivable                                0.0
# Inventory                                17046406000.0
# Other Current Assets                               0.0
# Total Current Assets                     40488254000.0
# Property, Plant and Equipment            15680247000.0
# Goodwill                                           0.0
# Intangible Assets                            8718000.0
# Long Term Investments                              0.0
# Tax Assets                                 481354000.0
# Other Fixed Assets                         335800000.0
# Fixed Assets                             16506119000.0
# Other Assets                                       0.0
# Total Assets                             56994373000.0
# Accounts Payable                         22002295000.0
# Short Term Debt                           2337952000.0
# Tax Payables                               363200000.0
# Deferred Revenue                                   0.0
# Other Current Liabilities                 5802591000.0
# Total Current Liabilities                30142838000.0
# Long Term Debt                             591275000.0
# Deferred Revenue Non Current               230558000.0
# Deferred Tax Liabilities                   394633000.0
# Other Non Current Liabilities                      0.0
# Total Non Current Liabilities             1216466000.0
# Other Liabilities                                  0.0
# Capital Lease Obligations                  924921000.0
# Total Liabilities                        31359304000.0
# Preferred Stock                                    0.0
# Common Stock                              4052228000.0
# Retained Earnings                        20832564000.0
# Accumulated Other Comprehensive Income             0.0
# Other Total Shareholder Equity             750277000.0
# Total Shareholder Equity                 25635069000.0
# Total Equity                             25635069000.0
# Total Liabilities and Shareholder Equity 56994373000.0
# Minority Interest                                  0.0
# Total Liabilities and Equity             56994373000.0
# Total Investments                          335800000.0
# Total Debt                                2929227000.0
# Net Debt                                 -3314451000.0

# %%
income_statement.head(50)
# Out:
# date                                                  2018          2019  \
# Revenue                                      41047139000.0 53028376000.0
# Cost of Goods Sold                           36875156000.0 49071048000.0
# Gross Profit                                  4171983000.0  3957328000.0
# Gross Profit Ratio                                  0.1016        0.0746
# Research and Development Expenses             1588654000.0  2087846000.0
# General and Administrative Expenses            535819000.0   619132000.0
# Selling and Marketing Expenses                 229238000.0   256786000.0
# Selling, General and Administrative Expenses   765057000.0   875918000.0
# Other Expenses                                  51002000.0    65771000.0
# Operating Expenses                            1739165000.0  2390619000.0
# Cost and Expenses                            38614321000.0 51461667000.0
# Interest Income                                 50800000.0    53683000.0
# Interest Expense                                42805000.0    31218000.0
# Depreciation and Amortization                 1925553000.0  2275909000.0
# EBITDA                                        4561523000.0  4040483000.0
# EBITDA Ratio                                        0.1111        0.0762
# Operating Income                              2635970000.0  1764574000.0
# Operating Income Ratio                              0.0642        0.0333
# Total Other Income                            -100138000.0   -68374000.0
# Income Before Tax                             2535832000.0  1696200000.0
# Income Before Tax Ratio                             0.0618         0.032
# Income Tax Expense                             347212000.0    98555000.0
# Net Income                                    2188620000.0  1597645000.0
# Net Income Ratio                                    0.0533        0.0301
# EPS                                                  48.57          35.5
# EPS Diluted                                          48.57          35.5
# Weighted Average Shares                         45064090.0    45064090.0
# Weighted Average Shares Diluted                 45064090.0    45064090.0
#
# date                                                  2020          2021  \
# Revenue                                      73121075000.0 89056978000.0
# Cost of Goods Sold                           63492232000.0 83027813000.0
# Gross Profit                                  9628843000.0  6029165000.0
# Gross Profit Ratio                                  0.1317        0.0677
# Research and Development Expenses             2913274000.0  3308296000.0
# General and Administrative Expenses            673164000.0  1041338000.0
# Selling and Marketing Expenses                 236855000.0   274578000.0
# Selling, General and Administrative Expenses   910019000.0  1315916000.0
# Other Expenses                                -242690000.0    36447000.0
# Operating Expenses                            3145284000.0  3631294000.0
# Cost and Expenses                            66637516000.0 86659107000.0
# Interest Income                                 50468000.0    79598000.0
# Interest Expense                                71333000.0    43329000.0
# Depreciation and Amortization                 2042129000.0  2557006000.0
# EBITDA                                        8333466000.0  5070922000.0
# EBITDA Ratio                                         0.114        0.0569
# Operating Income                              6291337000.0  2513916000.0
# Operating Income Ratio                               0.086        0.0282
# Total Other Income                             -70535000.0   -48623000.0
# Income Before Tax                             6220802000.0  2465293000.0
# Income Before Tax Ratio                             0.0851        0.0277
# Income Tax Expense                             779431000.0   155411000.0
# Net Income                                    5441371000.0  2309882000.0
# Net Income Ratio                                    0.0744        0.0259
# EPS                                                  120.5          51.5
# EPS Diluted                                          120.5          51.5
# Weighted Average Shares                         45064090.0    45064090.0
# Weighted Average Shares Diluted                 45064090.0    45064090.0
#
# date                                                   2022
# Revenue                                      107186288000.0
# Cost of Goods Sold                           100836020000.0
# Gross Profit                                   6350268000.0
# Gross Profit Ratio                                   0.0592
# Research and Development Expenses              3969376000.0
# General and Administrative Expenses            1234549000.0
# Selling and Marketing Expenses                  535437000.0
# Selling, General and Administrative Expenses   1769986000.0
# Other Expenses                                  -53534000.0
# Operating Expenses                             5001395000.0
# Cost and Expenses                            105837415000.0
# Interest Income                                  51507000.0
# Interest Expense                                 58531000.0
# Depreciation and Amortization                  2916884000.0
# EBITDA                                         4937601000.0
# EBITDA Ratio                                         0.0461
# Operating Income                               2020717000.0
# Operating Income Ratio                               0.0189
# Total Other Income                              -82147000.0
# Income Before Tax                              1938570000.0
# Income Before Tax Ratio                              0.0181
# Income Tax Expense                               80952000.0
# Net Income                                     1857618000.0
# Net Income Ratio                                     0.0173
# EPS                                                    41.0
# EPS Diluted                                            41.0
# Weighted Average Shares                          45064090.0
# Weighted Average Shares Diluted                  45064090.0

# %%
x = balance_sheet.loc['Short Term Investments'].get('2022')

# %%
y = balance_sheet.columns

# %%
max(y)
# Out:
# Period('2022', 'Y-DEC')

# %%
year = max(y)

# %%
z = balance_sheet.loc['Short Term Investments'][year]

# %%
z
# Out:
# 0.0
